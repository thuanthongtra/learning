# %% [markdown]
# # W1
# - Think Fast --> Self Service

# %% [markdown]
# # W2
# - Bulletproff Problem Solving

# %% [markdown]
# # W2&3
# - Structure Thinking --> Logic Tree
# - Qlik View Your Business --> How to decide Metrics, Drivers, Example of Cores Structure for Sales
# - garyfox.co/blog --> Business Model

# %% [markdown]
# - Lean Analytics: Use Data to Build a Better Startup Faster --> Considerations of Metrics
# - The Art of Data Analysis --> Storytelling
# - People Skills for Analytical Thinkers --> Storytelling
